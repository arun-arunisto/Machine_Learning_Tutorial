# %% [markdown]
# <a href="https://colab.research.google.com/github/arun-arunisto/Machine_Learning_Tutorial/blob/todo/MachineLearningTutorial2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pandas
# - Creating, Reading, Writing
# - Indexing, Selecting, Assigning
# - Summary functions and maps
# - Grouping and Sorting
# - Data types and Missing Values
# - Renaming and Combining

# %%
#importing pandas library
import pandas as pd

# %% [markdown]
# ##Creating Data
# - there are two core objects in pandas
# 1. Dataframe
# 2. Series

# %% [markdown]
# ###1. Dataframe
# - dataframe is a table
# - it contains an array of individual entries, each of which has a certain value
# - each entry corresponds row(or record) and column
# - we are using <b>pd.DataFrame()</b> constructor to generate these dataframe

# %%
#sample code
pd.DataFrame({"Name":["Arun", "Arunisto"], "Age":[27, 28]})
# Out:
#        Name  Age
# 0      Arun   27
# 1  Arunisto   28

# %%
#and also we can customize our own index also
pd.DataFrame({"Name":["Arun", "Arunisto"], "Age":[27, 28]},
             index=['Person 1', 'Person 2'])
# Out:
#               Name  Age
# Person 1      Arun   27
# Person 2  Arunisto   28

# %% [markdown]
# ###2. Series
# - series, by contrast is a sequence of data values.
# - if dataframe is a table "series" is a list
# - <b>pd.Series()</b> is going to create the series elements

# %%
#sample code
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# - a series id, in essence, a single column of a dataframe
# - so you can customize the index
# - series dont have a column name, it has only one overall name

# %%
pd.Series([5.0, 4.7, 4.5, 3.2],
          index=["Review 1", "Review 2", "Review 3", "Review 4"],
          name="Oppenheimer Movie")
# Out:
# Review 1    5.0
# Review 2    4.7
# Review 3    4.5
# Review 4    3.2
# Name: Oppenheimer Movie, dtype: float64

# %% [markdown]
# ##Reading data files
# - we are using "csv" file to read

# %%
#reading csv file
house_data = pd.read_csv("/content/drive/MyDrive/Datascience&MachineLearning/datasets/melb_data.csv")

# %%
#shape - to check how large the resulting dataframe
house_data.shape
# Out:
# (13580, 21)

# %% [markdown]
# - 13580 records with 21 different columns

# %%
#head() - which grabs the first five rows
house_data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %% [markdown]
# - we can specify the index by using index_col

# %% [markdown]
# ##Indexing, Selecting and Assigning
#
# - native python objects provide good ways to indexing data

# %%
house_data
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13575     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN        NaN        Yarra -37.79960   144.99840
# 1              79.0     1900.0        Yarra -37.80790   144.99340
# 2             150.0     1900.0        Yarra -37.80930   144.99440
# 3               NaN        NaN        Yarra -37.79690   144.99690
# 4             142.0     2014.0        Yarra -37.80720   144.99410
# ...             ...        ...          ...       ...         ...
# 13575           NaN     1981.0          NaN -37.90562   145.16761
# 13576         133.0     1995.0          NaN -37.85927   144.87904
# 13577           NaN     1997.0          NaN -37.85274   144.88738
# 13578         157.0     1920.0          NaN -37.85908   144.89299
# 13579         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [13580 rows x 21 columns]

# %% [markdown]
# - we are able to access the columns using "dot notation" like

# %%
#here we are accessing Suburb column
house_data.Suburb
# Out:
# 0           Abbotsford
# 1           Abbotsford
# 2           Abbotsford
# 3           Abbotsford
# 4           Abbotsford
#              ...
# 13575    Wheelers Hill
# 13576     Williamstown
# 13577     Williamstown
# 13578     Williamstown
# 13579       Yarraville
# Name: Suburb, Length: 13580, dtype: object

# %% [markdown]
# - and also we are able to access as a dictionary method using "[" "]" square brackets

# %%
#using [] and accessing Address column
house_data["Address"]
# Out:
# 0            85 Turner St
# 1         25 Bloomburg St
# 2            5 Charles St
# 3        40 Federation La
# 4             55a Park St
#                ...
# 13575        12 Strada Cr
# 13576       77 Merrett Dr
# 13577         83 Power St
# 13578        96 Verdon St
# 13579          6 Agnes St
# Name: Address, Length: 13580, dtype: object

# %% [markdown]
# - and we are able to take single data by using index positon

# %%
#using index position
house_data["Address"][0]
# Out:
# '85 Turner St'

# %% [markdown]
# ###indexing in pandas
# - in python default indexing operator to access elements that we above mentioned.
# - and pandas has also its own accessor operators <b>loc</b> and <b>iloc</b>

# %%
#iloc - index based selection
house_data.iloc[0]
# Out:
# Suburb                      Abbotsford
# Address                   85 Turner St
# Rooms                                2
# Type                                 h
# Price                        1480000.0
# Method                               S
# SellerG                         Biggin
# Date                         3/12/2016
# Distance                           2.5
# Postcode                        3067.0
# Bedroom2                           2.0
# Bathroom                           1.0
# Car                                1.0
# Landsize                         202.0
# BuildingArea                       NaN
# YearBuilt                          NaN
# CouncilArea                      Yarra
# Lattitude                     -37.7996
# Longtitude                    144.9984
# Regionname       Northern Metropolitan
# Propertycount                   4019.0
# Name: 0, dtype: object

# %% [markdown]
# - both "iloc" and "loc" are row-first, column-second
# - this is opposite in python, which is column first row second
# - this means that its marginally easier to retrieve rows, and marginally harder to get columns

# %%
house_data.iloc[:, 0] #it will get the only data of "suburb" column
# Out:
# 0           Abbotsford
# 1           Abbotsford
# 2           Abbotsford
# 3           Abbotsford
# 4           Abbotsford
#              ...
# 13575    Wheelers Hill
# 13576     Williamstown
# 13577     Williamstown
# 13578     Williamstown
# 13579       Yarraville
# Name: Suburb, Length: 13580, dtype: object

# %%
#next we are going to get 3 raws from first column
house_data.iloc[:3, 0]
# Out:
# 0    Abbotsford
# 1    Abbotsford
# 2    Abbotsford
# Name: Suburb, dtype: object

# %%
#or selecting the first and third entries
house_data.iloc[1:3, 0]
# Out:
# 1    Abbotsford
# 2    Abbotsford
# Name: Suburb, dtype: object

# %%
#it also possible to pass a list
house_data.iloc[[0, 1, 2], 0]
# Out:
# 0    Abbotsford
# 1    Abbotsford
# 2    Abbotsford
# Name: Suburb, dtype: object

# %%
#we can use negative index for starts from end
house_data[-5:] #it will return last 5 rows
# Out:
#               Suburb        Address  Rooms Type      Price Method   SellerG  \
# 13575  Wheelers Hill   12 Strada Cr      4    h  1245000.0      S     Barry
# 13576   Williamstown  77 Merrett Dr      3    h  1031000.0     SP  Williams
# 13577   Williamstown    83 Power St      3    h  1170000.0      S     Raine
# 13578   Williamstown   96 Verdon St      4    h  2500000.0     PI   Sweeney
# 13579     Yarraville     6 Agnes St      4    h  1285000.0     SP   Village
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 13575  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 13575           NaN     1981.0          NaN -37.90562   145.16761
# 13576         133.0     1995.0          NaN -37.85927   144.87904
# 13577           NaN     1997.0          NaN -37.85274   144.88738
# 13578         157.0     1920.0          NaN -37.85908   144.89299
# 13579         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [5 rows x 21 columns]

# %%
#loc - label based selection
house_data.loc[0, 'Suburb']
# Out:
# 'Abbotsford'

# %% [markdown]
# - its the data index value not its position, which matters

# %%
house_data.loc[:, ['Suburb', 'Address', 'Rooms', 'Type']]
# Out:
#               Suburb           Address  Rooms Type
# 0         Abbotsford      85 Turner St      2    h
# 1         Abbotsford   25 Bloomburg St      2    h
# 2         Abbotsford      5 Charles St      3    h
# 3         Abbotsford  40 Federation La      3    h
# 4         Abbotsford       55a Park St      4    h
# ...              ...               ...    ...  ...
# 13575  Wheelers Hill      12 Strada Cr      4    h
# 13576   Williamstown     77 Merrett Dr      3    h
# 13577   Williamstown       83 Power St      3    h
# 13578   Williamstown      96 Verdon St      4    h
# 13579     Yarraville        6 Agnes St      4    h
#
# [13580 rows x 4 columns]

# %% [markdown]
# - "iloc" conceptfully simpler than "loc"
# - it ignores the dataset's indices
# - when we use "iloc" we treat dataset like a big matrix a list of lists
# - "loc", by contrast uses the information in the indices to do its work.

# %% [markdown]
# ###Manipulating the index
# - label-based selection derives its power from the labels in the index.
# - the index we use is not immutable
# - we can manipulate the index in any way we see it

# %%
#set_index() method - is used to do the job
house_data.set_index('SellerG')
# Out:
#                  Suburb           Address  Rooms Type      Price Method  \
# SellerG
# Biggin       Abbotsford      85 Turner St      2    h  1480000.0      S
# Biggin       Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# Biggin       Abbotsford      5 Charles St      3    h  1465000.0     SP
# Biggin       Abbotsford  40 Federation La      3    h   850000.0     PI
# Nelson       Abbotsford       55a Park St      4    h  1600000.0     VB
# ...                 ...               ...    ...  ...        ...    ...
# Barry     Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# Williams   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# Raine      Williamstown       83 Power St      3    h  1170000.0      S
# Sweeney    Williamstown      96 Verdon St      4    h  2500000.0     PI
# Village      Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#                 Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# SellerG
# Biggin     3/12/2016       2.5    3067.0       2.0       1.0  1.0     202.0
# Biggin     4/02/2016       2.5    3067.0       2.0       1.0  0.0     156.0
# Biggin     4/03/2017       2.5    3067.0       3.0       2.0  0.0     134.0
# Biggin     4/03/2017       2.5    3067.0       3.0       2.0  1.0      94.0
# Nelson     4/06/2016       2.5    3067.0       3.0       1.0  2.0     120.0
# ...              ...       ...       ...       ...       ...  ...       ...
# Barry     26/08/2017      16.7    3150.0       4.0       2.0  2.0     652.0
# Williams  26/08/2017       6.8    3016.0       3.0       2.0  2.0     333.0
# Raine     26/08/2017       6.8    3016.0       3.0       2.0  4.0     436.0
# Sweeney   26/08/2017       6.8    3016.0       4.0       1.0  5.0     866.0
# Village   26/08/2017       6.3    3013.0       4.0       1.0  1.0     362.0
#
#           BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# SellerG
# Biggin             NaN        NaN       Yarra  -37.79960   144.99840
# Biggin            79.0     1900.0       Yarra  -37.80790   144.99340
# Biggin           150.0     1900.0       Yarra  -37.80930   144.99440
# Biggin             NaN        NaN       Yarra  -37.79690   144.99690
# Nelson           142.0     2014.0       Yarra  -37.80720   144.99410
# ...                ...        ...         ...        ...         ...
# Barry              NaN     1981.0         NaN  -37.90562   145.16761
# Williams         133.0     1995.0         NaN  -37.85927   144.87904
# Raine              NaN     1997.0         NaN  -37.85274   144.88738
# Sweeney          157.0     1920.0         NaN  -37.85908   144.89299
# Village          112.0     1920.0         NaN  -37.81188   144.88449
#
#                           Regionname  Propertycount
# SellerG
# Biggin         Northern Metropolitan         4019.0
# Biggin         Northern Metropolitan         4019.0
# Biggin         Northern Metropolitan         4019.0
# Biggin         Northern Metropolitan         4019.0
# Nelson         Northern Metropolitan         4019.0
# ...                              ...            ...
# Barry     South-Eastern Metropolitan         7392.0
# Williams        Western Metropolitan         6380.0
# Raine           Western Metropolitan         6380.0
# Sweeney         Western Metropolitan         6380.0
# Village         Western Metropolitan         6543.0
#
# [13580 rows x 20 columns]

# %% [markdown]
# - this is useful when dataset index which is better than current one

# %% [markdown]
# ###Conditional Selection

# %%
#we are going to check that SellerG is 'Biggin'
house_data.SellerG == 'Biggin'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 13575    False
# 13576    False
# 13577    False
# 13578    False
# 13579    False
# Name: SellerG, Length: 13580, dtype: bool

# %% [markdown]
# - this wil form a True/False based data,
# we can add this information on "loc" to select relevant data

# %%
house_data.loc[house_data.SellerG == 'Biggin']
# Out:
#              Suburb             Address  Rooms Type      Price Method SellerG  \
# 0        Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 1        Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2        Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
# 3        Abbotsford    40 Federation La      3    h   850000.0     PI  Biggin
# 8        Abbotsford  6/241 Nicholson St      1    u   300000.0      S  Biggin
# ...             ...                 ...    ...  ...        ...    ...     ...
# 13480     Maidstone        3 Wallace St      3    h   735000.0      S  Biggin
# 13497  Moonee Ponds         53 Moore St      4    h  1305000.0     SP  Biggin
# 13505      Mulgrave   2229 Dandenong Rd      3    h   940000.0      S  Biggin
# 13523       Prahran      69 Greville St      4    h  2668000.0      S  Biggin
# 13531      Richmond       170 Coppin St      4    h  1800000.0      S  Biggin
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0       3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1       4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2       4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3       4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 8       8/10/2016       2.5    3067.0  ...       1.0  1.0       0.0
# ...           ...       ...       ...  ...       ...  ...       ...
# 13480  26/08/2017       6.4    3012.0  ...       1.0  1.0     167.0
# 13497  26/08/2017       6.2    3039.0  ...       1.0  1.0     449.0
# 13505  26/08/2017      18.8    3170.0  ...       2.0  3.0     709.0
# 13523  26/08/2017       4.6    3181.0  ...       2.0  2.0     383.0
# 13531  26/08/2017       2.4    3121.0  ...       1.0  4.0     418.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN        NaN        Yarra -37.79960   144.99840
# 1              79.0     1900.0        Yarra -37.80790   144.99340
# 2             150.0     1900.0        Yarra -37.80930   144.99440
# 3               NaN        NaN        Yarra -37.79690   144.99690
# 8               NaN        NaN        Yarra -37.80080   144.99730
# ...             ...        ...          ...       ...         ...
# 13480         110.0     2010.0          NaN -37.78817   144.87873
# 13497         129.0     1910.0          NaN -37.77081   144.92074
# 13505         140.0     1958.0          NaN -37.92811   145.14971
# 13523           NaN        NaN          NaN -37.84879   144.98882
# 13531           NaN        NaN          NaN -37.82368   145.00271
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 8           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13480        Western Metropolitan        3873.0
# 13497        Western Metropolitan        6232.0
# 13505  South-Eastern Metropolitan        7113.0
# 13523       Southern Metropolitan        7717.0
# 13531       Northern Metropolitan       14949.0
#
# [393 rows x 21 columns]

# %%
#and also we are able to check multiple data
#here we are checking the sellerg is biggin, and rooms will be more than 3
house_data.loc[(house_data.SellerG == 'Biggin') & (house_data.Rooms >= 3)]
# Out:
#              Suburb            Address  Rooms Type      Price Method SellerG  \
# 2        Abbotsford       5 Charles St      3    h  1465000.0     SP  Biggin
# 3        Abbotsford   40 Federation La      3    h   850000.0     PI  Biggin
# 31       Abbotsford       166 Gipps St      3    h  1290000.0      S  Biggin
# 32       Abbotsford     60 Stafford St      3    h  1290000.0      S  Biggin
# 1016      Braybrook        80 South Rd      4    h   645000.0     SP  Biggin
# ...             ...                ...    ...  ...        ...    ...     ...
# 13480     Maidstone       3 Wallace St      3    h   735000.0      S  Biggin
# 13497  Moonee Ponds        53 Moore St      4    h  1305000.0     SP  Biggin
# 13505      Mulgrave  2229 Dandenong Rd      3    h   940000.0      S  Biggin
# 13523       Prahran     69 Greville St      4    h  2668000.0      S  Biggin
# 13531      Richmond      170 Coppin St      4    h  1800000.0      S  Biggin
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 2       4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3       4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 31     25/02/2017       2.5    3067.0  ...       2.0  2.0     147.0
# 32     25/02/2017       2.5    3067.0  ...       1.0  1.0     168.0
# 1016    7/11/2016      10.8    3019.0  ...       2.0  1.0     283.0
# ...           ...       ...       ...  ...       ...  ...       ...
# 13480  26/08/2017       6.4    3012.0  ...       1.0  1.0     167.0
# 13497  26/08/2017       6.2    3039.0  ...       1.0  1.0     449.0
# 13505  26/08/2017      18.8    3170.0  ...       2.0  3.0     709.0
# 13523  26/08/2017       4.6    3181.0  ...       2.0  2.0     383.0
# 13531  26/08/2017       2.4    3121.0  ...       1.0  4.0     418.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 2             150.0     1900.0        Yarra -37.80930   144.99440
# 3               NaN        NaN        Yarra -37.79690   144.99690
# 31             18.0        NaN        Yarra -37.80500   144.99430
# 32            124.0     1950.0        Yarra -37.80070   144.99580
# 1016          154.0     1990.0  Maribyrnong -37.79080   144.84850
# ...             ...        ...          ...       ...         ...
# 13480         110.0     2010.0          NaN -37.78817   144.87873
# 13497         129.0     1910.0          NaN -37.77081   144.92074
# 13505         140.0     1958.0          NaN -37.92811   145.14971
# 13523           NaN        NaN          NaN -37.84879   144.98882
# 13531           NaN        NaN          NaN -37.82368   145.00271
#
#                        Regionname Propertycount
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 31          Northern Metropolitan        4019.0
# 32          Northern Metropolitan        4019.0
# 1016         Western Metropolitan        3589.0
# ...                           ...           ...
# 13480        Western Metropolitan        3873.0
# 13497        Western Metropolitan        6232.0
# 13505  South-Eastern Metropolitan        7113.0
# 13523       Southern Metropolitan        7717.0
# 13531       Northern Metropolitan       14949.0
#
# [202 rows x 21 columns]

# %%
#next we are going to use or "|" pipe
#we will take data with or based
house_data.loc[(house_data.SellerG == 'Biggin') | (house_data.Rooms >= 3)]
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13575     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN        NaN        Yarra -37.79960   144.99840
# 1              79.0     1900.0        Yarra -37.80790   144.99340
# 2             150.0     1900.0        Yarra -37.80930   144.99440
# 3               NaN        NaN        Yarra -37.79690   144.99690
# 4             142.0     2014.0        Yarra -37.80720   144.99410
# ...             ...        ...          ...       ...         ...
# 13575           NaN     1981.0          NaN -37.90562   145.16761
# 13576         133.0     1995.0          NaN -37.85927   144.87904
# 13577           NaN     1997.0          NaN -37.85274   144.88738
# 13578         157.0     1920.0          NaN -37.85908   144.89299
# 13579         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [9442 rows x 21 columns]

# %%
#isin - it will check the data is in the list
house_data.loc[house_data.SellerG.isin(['Biggin', 'Williams'])]
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford        85 Turner St      2    h  1480000.0      S
# 1        Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 2        Abbotsford        5 Charles St      3    h  1465000.0     SP
# 3        Abbotsford    40 Federation La      3    h   850000.0     PI
# 8        Abbotsford  6/241 Nicholson St      1    u   300000.0      S
# ...             ...                 ...    ...  ...        ...    ...
# 13497  Moonee Ponds         53 Moore St      4    h  1305000.0     SP
# 13505      Mulgrave   2229 Dandenong Rd      3    h   940000.0      S
# 13523       Prahran      69 Greville St      4    h  2668000.0      S
# 13531      Richmond       170 Coppin St      4    h  1800000.0      S
# 13576  Williamstown       77 Merrett Dr      3    h  1031000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 8        Biggin   8/10/2016       2.5    3067.0  ...       1.0  1.0       0.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13497    Biggin  26/08/2017       6.2    3039.0  ...       1.0  1.0     449.0
# 13505    Biggin  26/08/2017      18.8    3170.0  ...       2.0  3.0     709.0
# 13523    Biggin  26/08/2017       4.6    3181.0  ...       2.0  2.0     383.0
# 13531    Biggin  26/08/2017       2.4    3121.0  ...       1.0  4.0     418.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN        NaN        Yarra -37.79960   144.99840
# 1              79.0     1900.0        Yarra -37.80790   144.99340
# 2             150.0     1900.0        Yarra -37.80930   144.99440
# 3               NaN        NaN        Yarra -37.79690   144.99690
# 8               NaN        NaN        Yarra -37.80080   144.99730
# ...             ...        ...          ...       ...         ...
# 13497         129.0     1910.0          NaN -37.77081   144.92074
# 13505         140.0     1958.0          NaN -37.92811   145.14971
# 13523           NaN        NaN          NaN -37.84879   144.98882
# 13531           NaN        NaN          NaN -37.82368   145.00271
# 13576         133.0     1995.0          NaN -37.85927   144.87904
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 8           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13497        Western Metropolitan        6232.0
# 13505  South-Eastern Metropolitan        7113.0
# 13523       Southern Metropolitan        7717.0
# 13531       Northern Metropolitan       14949.0
# 13576        Western Metropolitan        6380.0
#
# [504 rows x 21 columns]

# %%
#notnull() - this will return not NaN
house_data.loc[house_data.Price.notnull()]
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13575     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN        NaN        Yarra -37.79960   144.99840
# 1              79.0     1900.0        Yarra -37.80790   144.99340
# 2             150.0     1900.0        Yarra -37.80930   144.99440
# 3               NaN        NaN        Yarra -37.79690   144.99690
# 4             142.0     2014.0        Yarra -37.80720   144.99410
# ...             ...        ...          ...       ...         ...
# 13575           NaN     1981.0          NaN -37.90562   145.16761
# 13576         133.0     1995.0          NaN -37.85927   144.87904
# 13577           NaN     1997.0          NaN -37.85274   144.88738
# 13578         157.0     1920.0          NaN -37.85908   144.89299
# 13579         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [13580 rows x 21 columns]

# %%
#assigning data into a column
#house_data['SellerG'] = 'Arun'
#house_data['SellerG']

# %% [markdown]
# ##Summary Functions and Maps

# %%
#summary functions
#describe() - this method generates a high-level summary of the attributes of the given column
house_data.Price.describe()
# Out:
# count    1.358000e+04
# mean     1.075684e+06
# std      6.393107e+05
# min      8.500000e+04
# 25%      6.500000e+05
# 50%      9.030000e+05
# 75%      1.330000e+06
# max      9.000000e+06
# Name: Price, dtype: float64

# %%
#to see the mean of the column we can use mean()
house_data.Price.mean()
# Out:
# 1075684.079455081

# %%
#to see a list of unique values for that unique()
house_data.SellerG.unique()
# Out:
# array(['Biggin', 'Nelson', 'Jellis', 'Greg', 'LITTLE', 'Collins', 'Kay',
#        'Beller', 'Marshall', 'Brad', 'Maddison', 'Barry', 'Considine',
#        'Rendina', 'Propertyau', 'McDonald', 'Prof.', 'Harcourts',
#        'hockingstuart', 'Thomson', 'Buxton', 'RT', "Sotheby's", 'Cayzer',
#        'Chisholm', 'Brace', 'Miles', 'McGrath', 'Love', 'Barlow',
#        'Sweeney', 'Village', 'Jas', 'Gunn&Co', 'Burnham', 'Williams',
#        'Compton', 'FN', 'Raine&Horne', 'Hunter', 'Noel', 'Hodges', 'Ray',
#        'Gary', 'Fletchers', 'Woodards', 'Raine', 'Walshe', 'Alexkarbon',
#        'Weda', 'Frank', 'Stockdale', 'Tim', 'Purplebricks', 'Moonee',
#        'HAR', 'Edward', 'Philip', 'RW', 'North', 'Ascend', 'Christopher',
#        'Mandy', 'R&H', 'Fletchers/One', 'Assisi', 'One', "O'Brien", 'C21',
#        'Bayside', 'Paul', 'First', 'Matthew', 'Anderson', 'Nick',
#        'Lindellas', 'Allens', 'Bells', 'Trimson', 'Douglas', 'YPA', 'GL',
#        "Tiernan's", 'J', 'Harrington', 'Dingle', 'Chambers', 'Peter',
#        'Grantham', 'hockingstuart/Advantage', "O'Donoghues", 'Bekdon',
#        'Ross', 'Garvey', 'Weast', 'Century', 'Kelly', 'Property',
#        "Private/Tiernan's", 'Australian', 'Rodney', "Abercromby's",
#        'Castran', 'iTRAK', 'Del', 'Nicholson', 'ASL', 'Re', 'RE',
#        'Darren', 'Parkes', 'Vic', 'Holland', 'Scott', 'Pride', 'Owen',
#        'Morleys', 'Wilson', 'Buxton/Advantage', 'Pagan', 'Joe', 'Red',
#        'Thomas', 'Caine', 'Naison', 'Sweeney/Advantage', 'Jason', 'Eview',
#        'Melbourne', "D'Aprano", 'CASTRAN', 'Morrison', 'Wood', 'Haughton',
#        'William', 'Coventry', 'Buckingham', 'Domain', 'Nardella', 'Reach',
#        'Walsh', 'LJ', 'Nguyen', 'Direct', 'Besser', 'Johnston', 'Redina',
#        'Clairmont', 'Changing', 'Galldon', 'MICM', 'Elite', 'Buxton/Find',
#        'W.B.', 'Leased', 'New', 'Geoff', 'hockingstuart/Barry', 'Blue',
#        'Whiting', 'Steveway', 'Parkinson', 'VICPROP', 'Charlton', 'S&L',
#        'Calder', 'Homes', 'Zahn', 'Mason', 'David', 'Dixon', 'Luxe',
#        'Prowse', 'Ken', 'iOne', 'hockingstuart/Village', 'JMRE', 'Iconek',
#        'Crane', 'Luxton', 'Hooper', 'Oak', 'White', 'Weston', 'Reed',
#        'Oriental', 'Craig', 'Max', 'Rosin', 'Real', 'Hall', 'Ham',
#        'buyMyplace', 'WHITEFOX', 'Metro', 'Hoskins', 'McLennan',
#        'PRDNationwide', 'Only', 'Obrien', 'Reliance', 'Lucas', 'Rounds',
#        'Millership', 'iSell', 'Appleby', '@Realty', 'Jim', 'Ace', 'JRW',
#        'Carter', 'M.J', 'iProperty', 'Triwest', 'Hayeswinckle',
#        'Schroeder', 'VICProp', 'REMAX', 'Victory', 'Smart', 'Mindacom',
#        'Ryder', 'Win', 'Asset', 'LLC', 'Mitchell', 'U', 'Leyton',
#        'Conquest', 'Prime', 'Community', 'Free', 'Veitch', 'Peake',
#        'Sell', 'Ristic', 'Ash', 'Upper', 'Daniel', 'Xynergy', 'Westside',
#        'Leeburn', 'TRUE', 'Keatings', 'Leading', 'Bullen', 'Better',
#        'Aquire', 'Langwell', 'Gardiner', 'Kaye', 'Nicholls', 'Bowman',
#        'Meadows', 'McNaughton', 'The', 'L', 'Darras', 'Roger', 'Follett',
#        'Le', 'Joseph', 'Boutique', 'Area', 'SN', 'PRD', 'Rexhepi',
#        'Point'], dtype=object)

# %%
#to count the unique values value_counts()
house_data.SellerG.value_counts()
# Out:
# Nelson           1565
# Jellis           1316
# hockingstuart    1167
# Barry            1011
# Ray               701
#                  ...
# Prowse              1
# Luxe                1
# Zahn                1
# Homes               1
# Point               1
# Name: SellerG, Length: 268, dtype: int64

# %%
#map() - method takes set values and "maps" them to set of another values
house_data_price_mean = house_data.Price.mean()
house_data.Price.map(lambda p: p-house_data_price_mean)
# Out:
# 0        4.043159e+05
# 1       -4.068408e+04
# 2        3.893159e+05
# 3       -2.256841e+05
# 4        5.243159e+05
#              ...
# 13575    1.693159e+05
# 13576   -4.468408e+04
# 13577    9.431592e+04
# 13578    1.424316e+06
# 13579    2.093159e+05
# Name: Price, Length: 13580, dtype: float64

# %% [markdown]
# - The function you pass to map() should expect a single value from the Series (a point value, in the above example), and return a transformed version of that value. map() returns a new Series where all the values have been transformed by your function.

# %%
#so we use apply() is also the equivalent method to transform data
def remean_price(row):
  row.Price = row.Price - house_data_price_mean
  return row

house_data.apply(remean_price, axis="columns")
# Out:
#               Suburb           Address  Rooms Type         Price Method  \
# 0         Abbotsford      85 Turner St      2    h  4.043159e+05      S
# 1         Abbotsford   25 Bloomburg St      2    h -4.068408e+04      S
# 2         Abbotsford      5 Charles St      3    h  3.893159e+05     SP
# 3         Abbotsford  40 Federation La      3    h -2.256841e+05     PI
# 4         Abbotsford       55a Park St      4    h  5.243159e+05     VB
# ...              ...               ...    ...  ...           ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1.693159e+05      S
# 13576   Williamstown     77 Merrett Dr      3    h -4.468408e+04     SP
# 13577   Williamstown       83 Power St      3    h  9.431592e+04      S
# 13578   Williamstown      96 Verdon St      4    h  1.424316e+06     PI
# 13579     Yarraville        6 Agnes St      4    h  2.093159e+05     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13575     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN        NaN        Yarra -37.79960   144.99840
# 1              79.0     1900.0        Yarra -37.80790   144.99340
# 2             150.0     1900.0        Yarra -37.80930   144.99440
# 3               NaN        NaN        Yarra -37.79690   144.99690
# 4             142.0     2014.0        Yarra -37.80720   144.99410
# ...             ...        ...          ...       ...         ...
# 13575           NaN     1981.0          NaN -37.90562   145.16761
# 13576         133.0     1995.0          NaN -37.85927   144.87904
# 13577           NaN     1997.0          NaN -37.85274   144.88738
# 13578         157.0     1920.0          NaN -37.85908   144.89299
# 13579         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [13580 rows x 21 columns]

# %% [markdown]
# - note that map() and apply() return new data they dont alter existing data

# %%
#we are going take the data and check it its change
house_data.head(1)
# Out:
#        Suburb       Address  Rooms Type      Price Method SellerG       Date  \
# 0  Abbotsford  85 Turner St      2    h  1480000.0      S  Biggin  3/12/2016
#
#    Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 0       2.5    3067.0  ...       1.0  1.0     202.0           NaN        NaN
#
#    CouncilArea Lattitude  Longtitude             Regionname Propertycount
# 0        Yarra  -37.7996    144.9984  Northern Metropolitan        4019.0
#
# [1 rows x 21 columns]

# %% [markdown]
# ##Grouping and Sorting
# - maps allows us to transform data in a dataframe one value at a time for an entire column
# - we use groupby() for group our data and then do something specific to the group

# %%
#group wise analysis using group_by() function
house_data.groupby('Car').Car.count()
# Out:
# Car
# 0.0     1026
# 1.0     5509
# 2.0     5591
# 3.0      748
# 4.0      506
# 5.0       63
# 6.0       54
# 7.0        8
# 8.0        9
# 9.0        1
# 10.0       3
# Name: Car, dtype: int64

# %%
#so we are going to grouping the car and getting data with low price
house_data.groupby('Car').Price.min()
# Out:
# Car
# 0.0       85000.0
# 1.0      145000.0
# 2.0      131000.0
# 3.0      370000.0
# 4.0      295000.0
# 5.0      531000.0
# 6.0      451000.0
# 7.0      560000.0
# 8.0      580000.0
# 9.0     2100000.0
# 10.0     880000.0
# Name: Price, dtype: float64

# %%
#applying groupby using lambda
house_data.groupby('Price').apply(lambda df: df.Suburb.iloc[0])
# Out:
# Price
# 85000.0        Footscray
# 131000.0       Caulfield
# 145000.0          Coburg
# 160000.0        Hawthorn
# 170000.0       Footscray
#                 ...
# 6400000.0    Middle Park
# 6500000.0            Kew
# 7650000.0       Hawthorn
# 8000000.0     Canterbury
# 9000000.0       Mulgrave
# Length: 2204, dtype: object

# %%
#applying groupby with two column using lambda
house_data.groupby(['Car', 'Price']).apply(lambda df: df.loc[df.Rooms.idxmax()])
# Out:
#                       Suburb               Address  Rooms Type      Price  \
# Car  Price
# 0.0  85000.0       Footscray      202/51 Gordon St      1    u    85000.0
#      160000.0       Hawthorn         17/17 Park St      1    u   160000.0
#      170000.0      Footscray      10/30 Pickett St      1    u   170000.0
#      210000.0      Melbourne      928/43 Therry St      1    u   210000.0
#      222000.0   Moonee Ponds  7/110 Maribyrnong Rd      1    u   222000.0
# ...                      ...                   ...    ...  ...        ...
# 8.0  3850000.0     Northcote         215 Clarke St      4    h  3850000.0
# 9.0  2100000.0  Surrey Hills    1093 Riversdale Rd      3    h  2100000.0
# 10.0 880000.0      Dandenong    1462 Heatherton Rd      3    h   880000.0
#      925000.0      Bayswater          95 Orange Gr      4    h   925000.0
#      1112000.0     Reservoir              1 Don St      4    h  1112000.0
#
#                Method  SellerG        Date  Distance  Postcode  ...  Bathroom  \
# Car  Price                                                      ...
# 0.0  85000.0       PI  Burnham   3/09/2016       6.4    3011.0  ...       1.0
#      160000.0      VB      HAR   8/04/2017       4.6    3122.0  ...       1.0
#      170000.0      PI  Burnham   1/07/2017       5.1    3011.0  ...       1.0
#      210000.0      VB     Greg  13/08/2016       2.8    3000.0  ...       1.0
#      222000.0       S    Barry  17/06/2017       6.2    3039.0  ...       1.0
# ...               ...      ...         ...       ...       ...  ...       ...
# 8.0  3850000.0     PI   Jellis  30/07/2016       5.5    3070.0  ...       4.0
# 9.0  2100000.0     VB   Jellis   1/07/2017      10.2    3127.0  ...       1.0
# 10.0 880000.0       S    Barry  22/07/2017      24.7    3175.0  ...       2.0
#      925000.0      SP   Biggin  17/06/2017      23.2    3153.0  ...       1.0
#      1112000.0      S       RW  26/08/2017      12.0    3073.0  ...       2.0
#
#                  Car  Landsize  BuildingArea  YearBuilt        CouncilArea  \
# Car  Price
# 0.0  85000.0     0.0       0.0           NaN     2007.0        Maribyrnong
#      160000.0    0.0     322.0           NaN     2009.0         Boroondara
#      170000.0    0.0      30.0          26.0     2013.0        Maribyrnong
#      210000.0    0.0       0.0           NaN        NaN          Melbourne
#      222000.0    0.0       0.0          29.0     2012.0      Moonee Valley
# ...              ...       ...           ...        ...                ...
# 8.0  3850000.0   8.0    1390.0           NaN     1912.0            Darebin
# 9.0  2100000.0   9.0     841.0         124.0     1960.0         Whitehorse
# 10.0 880000.0   10.0     734.0           NaN        NaN  Greater Dandenong
#      925000.0   10.0     993.0         128.0     1966.0               Knox
#      1112000.0  10.0    1002.0         170.0     1985.0                NaN
#
#                Lattitude  Longtitude                  Regionname Propertycount
# Car  Price
# 0.0  85000.0   -37.79110   144.89000        Western Metropolitan        7570.0
#      160000.0  -37.81980   145.03730       Southern Metropolitan       11308.0
#      170000.0  -37.80141   144.89587        Western Metropolitan        7570.0
#      210000.0  -37.80780   144.96100       Northern Metropolitan       17496.0
#      222000.0  -37.77154   144.91597        Western Metropolitan        6232.0
# ...                  ...         ...                         ...           ...
# 8.0  3850000.0 -37.77670   144.99960       Northern Metropolitan       11364.0
# 9.0  2100000.0 -37.83729   145.10929       Southern Metropolitan        5457.0
# 10.0 880000.0  -37.96969   145.21043  South-Eastern Metropolitan       10894.0
#      925000.0  -37.84688   145.25632        Eastern Metropolitan        5030.0
#      1112000.0 -37.70671   145.03086       Northern Metropolitan       21650.0
#
# [4270 rows x 21 columns]

# %%
#using agg() function and running a bunch of different functions
house_data.groupby(['Suburb']).Price.agg([len, min, max])
# Out:
#               len       min        max
# Suburb
# Abbotsford     56  300000.0  1876000.0
# Aberfeldie     44  280000.0  3900000.0
# Airport West   67  440000.0  1250000.0
# Albanvale       6  415000.0   655000.0
# Albert Park    69  442500.0  4735000.0
# ...           ...       ...        ...
# Wonga Park      1  900000.0   900000.0
# Wyndham Vale    4  475000.0   500000.0
# Yallambie      24  602500.0  1670000.0
# Yarra Glen      1  620000.0   620000.0
# Yarraville    164  330000.0  2450000.0
#
# [314 rows x 3 columns]

# %%
#multi-indexes agg()
house_data_reviewed = house_data.groupby(['SellerG', 'Car']).Suburb.agg([len])
house_data_reviewed
# Out:
#                   len
# SellerG      Car
# @Realty      0.0    1
#              3.0    1
# ASL          1.0    2
#              2.0    2
# Abercromby's 0.0    1
# ...               ...
# iTRAK        1.0    2
#              2.0    5
#              3.0    2
#              4.0    2
#              8.0    1
#
# [743 rows x 1 columns]

# %%
mi = house_data_reviewed.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
#reset_index() to converting back to regular index
house_data_reviewed.reset_index()
# Out:
#           SellerG  Car  len
# 0         @Realty  0.0    1
# 1         @Realty  3.0    1
# 2             ASL  1.0    2
# 3             ASL  2.0    2
# 4    Abercromby's  0.0    1
# ..            ...  ...  ...
# 738         iTRAK  1.0    2
# 739         iTRAK  2.0    5
# 740         iTRAK  3.0    2
# 741         iTRAK  4.0    2
# 742         iTRAK  8.0    1
#
# [743 rows x 3 columns]

# %%
#sorting - to get data in the order want it in we can sort it ourselves
#sort_values()
house_data_reviewed = house_data_reviewed.reset_index()
house_data_reviewed.sort_values(by='len')
# Out:
#            SellerG  Car  len
# 0          @Realty  0.0    1
# 415      Melbourne  6.0    1
# 414      Melbourne  5.0    1
# 413      Melbourne  3.0    1
# 410        Meadows  2.0    1
# ..             ...  ...  ...
# 32           Barry  2.0  492
# 722  hockingstuart  1.0  523
# 309         Jellis  1.0  529
# 443         Nelson  2.0  561
# 442         Nelson  1.0  732
#
# [743 rows x 3 columns]

# %%
#you can also set ascending and descending
house_data_reviewed.sort_values(by='len', ascending=False)
# Out:
#            SellerG  Car  len
# 442         Nelson  1.0  732
# 443         Nelson  2.0  561
# 309         Jellis  1.0  529
# 722  hockingstuart  1.0  523
# 32           Barry  2.0  492
# ..             ...  ...  ...
# 352        Leeburn  4.0    1
# 350        Leeburn  1.0    1
# 348         Leased  0.0    1
# 347        Leading  4.0    1
# 742          iTRAK  8.0    1
#
# [743 rows x 3 columns]

# %%
#to sort by index values we can use sort_index()
house_data_reviewed.sort_index()
# Out:
#           SellerG  Car  len
# 0         @Realty  0.0    1
# 1         @Realty  3.0    1
# 2             ASL  1.0    2
# 3             ASL  2.0    2
# 4    Abercromby's  0.0    1
# ..            ...  ...  ...
# 738         iTRAK  1.0    2
# 739         iTRAK  2.0    5
# 740         iTRAK  3.0    2
# 741         iTRAK  4.0    2
# 742         iTRAK  8.0    1
#
# [743 rows x 3 columns]

# %%
#and also we can sort by more than one column at a time
house_data_reviewed.sort_values(by=['Car', 'len'])
# Out:
#           SellerG   Car  len
# 0         @Realty   0.0    1
# 4    Abercromby's   0.0    1
# 19         Ascend   0.0    1
# 26         Barlow   0.0    1
# 68          Brace   0.0    1
# ..            ...   ...  ...
# 316        Jellis   8.0    3
# 317        Jellis   9.0    1
# 39          Barry  10.0    1
# 64         Biggin  10.0    1
# 549            RW  10.0    1
#
# [743 rows x 3 columns]

# %% [markdown]
# ##Data types and missing values

# %%
#to find data type use dtype
house_data.Price.dtype
# Out:
# dtype('float64')

# %%
#and also we can find datatypes of every column
house_data.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
#data type conversion also possible by using 'astype()'
house_data.Rooms.astype('float64')
# Out:
# 0        2.0
# 1        2.0
# 2        3.0
# 3        3.0
# 4        4.0
#         ...
# 13575    4.0
# 13576    3.0
# 13577    3.0
# 13578    4.0
# 13579    4.0
# Name: Rooms, Length: 13580, dtype: float64

# %%
#and index has its own dtype
house_data.index.dtype
# Out:
# dtype('int64')

# %%
#we can find missing values NaN("Not a Number")
#to find NaN entries you can use .isnull() function
#and also we can find not NaN values by using .notnull()
house_data[pd.isnull(house_data.CouncilArea)]
# Out:
#               Suburb         Address  Rooms Type      Price Method  \
# 7584   Brighton East    7 Roberts Ct      3    h  1270000.0     VB
# 10797      Reservoir  48 Crevelli St      3    h   526250.0     SP
# 12213     Aberfeldie       1 Alma St      4    h  1436000.0      S
# 12214         Albion    40 Ridley St      5    h   905000.0      S
# 12215     Alphington    22 Harker St      4    h  1680000.0      S
# ...              ...             ...    ...  ...        ...    ...
# 13575  Wheelers Hill    12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown   77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown     83 Power St      3    h  1170000.0      S
# 13578   Williamstown    96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville      6 Agnes St      4    h  1285000.0     SP
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 7584             Ray  20/05/2017      10.7    3187.0  ...       1.0  3.0
# 10797          Barry   8/07/2017      12.0    3073.0  ...       1.0  1.0
# 12213           Brad   3/09/2017       7.5    3040.0  ...       3.0  3.0
# 12214  hockingstuart   3/09/2017      10.5    3020.0  ...       2.0  3.0
# 12215           Love   3/09/2017       5.7    3078.0  ...       3.0  2.0
# ...              ...         ...       ...       ...  ...       ...  ...
# 13575          Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0
# 13576       Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0
# 13577          Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0
# 13578        Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0
# 13579        Village  26/08/2017       6.3    3013.0  ...       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 7584      724.0           NaN        NaN          NaN -37.92910   145.02970
# 10797     308.0           NaN        NaN          NaN -37.72828   145.03033
# 12213     511.0         187.0     1922.0          NaN -37.75788   144.90487
# 12214     732.0           NaN     1925.0          NaN -37.78345   144.82295
# 12215     720.0           NaN        NaN          NaN -37.77928   145.02993
# ...         ...           ...        ...          ...       ...         ...
# 13575     652.0           NaN     1981.0          NaN -37.90562   145.16761
# 13576     333.0         133.0     1995.0          NaN -37.85927   144.87904
# 13577     436.0           NaN     1997.0          NaN -37.85274   144.88738
# 13578     866.0         157.0     1920.0          NaN -37.85908   144.89299
# 13579     362.0         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 7584        Southern Metropolitan        6938.0
# 10797       Northern Metropolitan       21650.0
# 12213        Western Metropolitan        1543.0
# 12214        Western Metropolitan        2185.0
# 12215       Northern Metropolitan        2211.0
# ...                           ...           ...
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [1369 rows x 21 columns]

# %%
#and also youre able to replace the missing values
house_data.CouncilArea.fillna('Unknown')
# Out:
# 0          Yarra
# 1          Yarra
# 2          Yarra
# 3          Yarra
# 4          Yarra
#           ...
# 13575    Unknown
# 13576    Unknown
# 13577    Unknown
# 13578    Unknown
# 13579    Unknown
# Name: CouncilArea, Length: 13580, dtype: object

# %%
#and also you can replace() values by using replace method
house_data.SellerG.replace('Barry', 'Arunisto')
# Out:
# 0          Biggin
# 1          Biggin
# 2          Biggin
# 3          Biggin
# 4          Nelson
#            ...
# 13575    Arunisto
# 13576    Williams
# 13577       Raine
# 13578     Sweeney
# 13579     Village
# Name: SellerG, Length: 13580, dtype: object

# %% [markdown]
# ##Renaming and Combining

# %%
#you can rename columns by using rename() method
house_data.rename(columns={'SellerG':'Owner'})
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#           Owner        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13575     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN        NaN        Yarra -37.79960   144.99840
# 1              79.0     1900.0        Yarra -37.80790   144.99340
# 2             150.0     1900.0        Yarra -37.80930   144.99440
# 3               NaN        NaN        Yarra -37.79690   144.99690
# 4             142.0     2014.0        Yarra -37.80720   144.99410
# ...             ...        ...          ...       ...         ...
# 13575           NaN     1981.0          NaN -37.90562   145.16761
# 13576         133.0     1995.0          NaN -37.85927   144.87904
# 13577           NaN     1997.0          NaN -37.85274   144.88738
# 13578         157.0     1920.0          NaN -37.85908   144.89299
# 13579         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [13580 rows x 21 columns]

# %%
#rename() and you can rename index or column values
house_data.rename(index={0:'FirstEntry', 1:'SecondEntry'})
# Out:
#                     Suburb           Address  Rooms Type      Price Method  \
# FirstEntry      Abbotsford      85 Turner St      2    h  1480000.0      S
# SecondEntry     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2               Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3               Abbotsford  40 Federation La      3    h   850000.0     PI
# 4               Abbotsford       55a Park St      4    h  1600000.0     VB
# ...                    ...               ...    ...  ...        ...    ...
# 13575        Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576         Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577         Williamstown       83 Power St      3    h  1170000.0      S
# 13578         Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579           Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#               SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# FirstEntry     Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0
# SecondEntry    Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0
# 2              Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0
# 3              Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0
# 4              Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0
# ...               ...         ...       ...       ...  ...       ...  ...
# 13575           Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0
# 13576        Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0
# 13577           Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0
# 13578         Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0
# 13579         Village  26/08/2017       6.3    3013.0  ...       1.0  1.0
#
#              Landsize  BuildingArea  YearBuilt  CouncilArea Lattitude  \
# FirstEntry      202.0           NaN        NaN        Yarra -37.79960
# SecondEntry     156.0          79.0     1900.0        Yarra -37.80790
# 2               134.0         150.0     1900.0        Yarra -37.80930
# 3                94.0           NaN        NaN        Yarra -37.79690
# 4               120.0         142.0     2014.0        Yarra -37.80720
# ...               ...           ...        ...          ...       ...
# 13575           652.0           NaN     1981.0          NaN -37.90562
# 13576           333.0         133.0     1995.0          NaN -37.85927
# 13577           436.0           NaN     1997.0          NaN -37.85274
# 13578           866.0         157.0     1920.0          NaN -37.85908
# 13579           362.0         112.0     1920.0          NaN -37.81188
#
#              Longtitude                  Regionname Propertycount
# FirstEntry    144.99840       Northern Metropolitan        4019.0
# SecondEntry   144.99340       Northern Metropolitan        4019.0
# 2             144.99440       Northern Metropolitan        4019.0
# 3             144.99690       Northern Metropolitan        4019.0
# 4             144.99410       Northern Metropolitan        4019.0
# ...                 ...                         ...           ...
# 13575         145.16761  South-Eastern Metropolitan        7392.0
# 13576         144.87904        Western Metropolitan        6380.0
# 13577         144.88738        Western Metropolitan        6380.0
# 13578         144.89299        Western Metropolitan        6380.0
# 13579         144.88449        Western Metropolitan        6543.0
#
# [13580 rows x 21 columns]

# %%
#and also we can rename the axis by using rename_axis()
house_data.rename_axis("houses", axis="rows").rename_axis("fields", axis="columns")
# Out:
# fields         Suburb           Address  Rooms Type      Price Method  \
# houses
# 0          Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          Abbotsford       55a Park St      4    h  1600000.0     VB
# ...               ...               ...    ...  ...        ...    ...
# 13575   Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576    Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577    Williamstown       83 Power St      3    h  1170000.0      S
# 13578    Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579      Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# fields   SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# houses                                            ...
# 0         Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0
# 1         Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0
# 2         Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0
# 3         Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0
# 4         Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0
# ...          ...         ...       ...       ...  ...       ...  ...
# 13575      Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0
# 13576   Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0
# 13577      Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0
# 13578    Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0
# 13579    Village  26/08/2017       6.3    3013.0  ...       1.0  1.0
#
# fields  Landsize  BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# houses
# 0          202.0           NaN        NaN        Yarra -37.79960   144.99840
# 1          156.0          79.0     1900.0        Yarra -37.80790   144.99340
# 2          134.0         150.0     1900.0        Yarra -37.80930   144.99440
# 3           94.0           NaN        NaN        Yarra -37.79690   144.99690
# 4          120.0         142.0     2014.0        Yarra -37.80720   144.99410
# ...          ...           ...        ...          ...       ...         ...
# 13575      652.0           NaN     1981.0          NaN -37.90562   145.16761
# 13576      333.0         133.0     1995.0          NaN -37.85927   144.87904
# 13577      436.0           NaN     1997.0          NaN -37.85274   144.88738
# 13578      866.0         157.0     1920.0          NaN -37.85908   144.89299
# 13579      362.0         112.0     1920.0          NaN -37.81188   144.88449
#
# fields                  Regionname Propertycount
# houses
# 0            Northern Metropolitan        4019.0
# 1            Northern Metropolitan        4019.0
# 2            Northern Metropolitan        4019.0
# 3            Northern Metropolitan        4019.0
# 4            Northern Metropolitan        4019.0
# ...                            ...           ...
# 13575   South-Eastern Metropolitan        7392.0
# 13576         Western Metropolitan        6380.0
# 13577         Western Metropolitan        6380.0
# 13578         Western Metropolitan        6380.0
# 13579         Western Metropolitan        6543.0
#
# [13580 rows x 21 columns]

# %%
#and also we can combine two datasets
#we use concat(), join(), and merge()
us_youtube = pd.read_csv('/content/drive/MyDrive/Datascience&MachineLearning/datasets/USvideos.csv')
in_youtube = pd.read_csv('/content/drive/MyDrive/Datascience&MachineLearning/datasets/INvideos.csv')
pd.concat([us_youtube, in_youtube])
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 37347  iNHecA3PJCo      18.14.06
# 37348  dpPmPbhcslM      18.14.06
# 37349  mV6aztP58f8      18.14.06
# 37350  qxqDNP1bDEw      18.14.06
# 37351  wERgpPK44w0      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 37347  फेकू आशिक़ - राजस्थान की सबसे शानदार कॉमेडी | ...
# 37348                         Seetha | Flowers | Ep# 364
# 37349  Bhramanam I Episode 87 - 12 June 2018 I Mazhav...
# 37350  Nua Bohu | Full Ep 285 | 13th June 2018 | Odia...
# 37351  Ee Nagaraniki Emaindi Trailer | Tharun Bhascke...
#
#                channel_title  category_id              publish_time  \
# 0               CaseyNeistat           22  2017-11-13T17:13:01.000Z
# 1            LastWeekTonight           24  2017-11-13T07:30:00.000Z
# 2               Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# 3      Good Mythical Morning           24  2017-11-13T11:00:04.000Z
# 4                   nigahiga           24  2017-11-12T18:01:41.000Z
# ...                      ...          ...                       ...
# 37347         RDC Rajasthani           23  2018-06-13T08:01:11.000Z
# 37348             Flowers TV           24  2018-06-13T11:30:04.000Z
# 37349      Mazhavil Manorama           24  2018-06-13T05:00:02.000Z
# 37350              Tarang TV           24  2018-06-13T15:07:49.000Z
# 37351     Suresh Productions           24  2018-06-10T04:29:54.000Z
#
#                                                     tags    views   likes  \
# 0                                        SHANtell martin   748374   57527
# 1      last week tonight trump presidency|"last week ...  2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
# ...                                                  ...      ...     ...
# 37347  twinkle vaishnav comedy|"twinkle vaishnav"|"tw...   214378    3291
# 37348  flowers serials|"actress"|"malayalam serials"|...   406828    1726
# 37349  mazhavil manorama|"bhramanam full episode"|"gt...   386319    1216
# 37350  tarang|"tarang tv"|"tarang tv online"|"tarang ...   130263     698
# 37351  Ee Nagaraniki Emaindi|"Ee Nagaraniki Emaindi T...  1278249   22466
#
#        dislikes  comment_count  \
# 0          2966          15954
# 1          6146          12703
# 2          5339           8181
# 3           666           2146
# 4          1989          17518
# ...         ...            ...
# 37347       404            196
# 37348       478           1428
# 37349       453            697
# 37350       115             65
# 37351      1609           1205
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg              False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# ...                                               ...                ...
# 37347  https://i.ytimg.com/vi/iNHecA3PJCo/default.jpg              False
# 37348  https://i.ytimg.com/vi/dpPmPbhcslM/default.jpg              False
# 37349  https://i.ytimg.com/vi/mV6aztP58f8/default.jpg              False
# 37350  https://i.ytimg.com/vi/qxqDNP1bDEw/default.jpg              False
# 37351  https://i.ytimg.com/vi/wERgpPK44w0/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 37347             False                   False
# 37348             False                   False
# 37349             False                   False
# 37350             False                   False
# 37351             False                   False
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 37347  PRG Music & RDC Rajasthani presents फेकू आशिक़...
# 37348  Flowers - A R Rahman Show,Book your Tickets He...
# 37349  Subscribe to Mazhavil Manorama now for your da...
# 37350  Nuabohu : Story of a rustic village girl who w...
# 37351  Check out Ee Nagaraniki Emaindi Trailer #EeNag...
#
# [78301 rows x 16 columns]

# %%
#join() you can combine different data frame objects
#for eg, we are going to pull down videos that happened trending on the same day
#in both India and the US
left = us_youtube.set_index(['title', 'trending_date'])
right = in_youtube.set_index(['title', 'trending_date'])
left.join(right, lsuffix='_US', rsuffix='_IN')
# Out:
#                                                           video_id_US  \
# title                                      trending_date
# #184 Making a PCB using EasyEDA. // Review 17.07.12       BPmgDhwbd1w
# #23 Feed The Homeless | One List, One Life 17.01.12       4qakFfGRV4E
#                                            17.02.12       4qakFfGRV4E
#                                            17.03.12       4qakFfGRV4E
#                                            17.04.12       4qakFfGRV4E
# ...                                                               ...
# 🎃 How to make Pumpkin Pie Mistakes         17.28.11       bAfn2duIlN8
#                                            17.29.11       bAfn2duIlN8
# 😱 $1,145 iPhone Case!!                     18.04.02       r3J784MSRyQ
#                                            18.05.02       r3J784MSRyQ
#                                            18.06.02       r3J784MSRyQ
#
#                                                              channel_title_US  \
# title                                      trending_date
# #184 Making a PCB using EasyEDA. // Review 17.07.12                  MickMake
# #23 Feed The Homeless | One List, One Life 17.01.12       One List , One Life
#                                            17.02.12       One List , One Life
#                                            17.03.12       One List , One Life
#                                            17.04.12       One List , One Life
# ...                                                                       ...
# 🎃 How to make Pumpkin Pie Mistakes         17.28.11                  iJustine
#                                            17.29.11                  iJustine
# 😱 $1,145 iPhone Case!!                     18.04.02                  iJustine
#                                            18.05.02                  iJustine
#                                            18.06.02                  iJustine
#
#                                                           category_id_US  \
# title                                      trending_date
# #184 Making a PCB using EasyEDA. // Review 17.07.12                   28
# #23 Feed The Homeless | One List, One Life 17.01.12                   22
#                                            17.02.12                   22
#                                            17.03.12                   22
#                                            17.04.12                   22
# ...                                                                  ...
# 🎃 How to make Pumpkin Pie Mistakes         17.28.11                   22
#                                            17.29.11                   22
# 😱 $1,145 iPhone Case!!                     18.04.02                   28
#                                            18.05.02                   28
#                                            18.06.02                   28
#
#                                                                    publish_time_US  \
# title                                      trending_date
# #184 Making a PCB using EasyEDA. // Review 17.07.12       2017-12-02T14:05:07.000Z
# #23 Feed The Homeless | One List, One Life 17.01.12       2017-11-30T15:36:12.000Z
#                                            17.02.12       2017-11-30T15:36:12.000Z
#                                            17.03.12       2017-11-30T15:36:12.000Z
#                                            17.04.12       2017-11-30T15:36:12.000Z
# ...                                                                            ...
# 🎃 How to make Pumpkin Pie Mistakes         17.28.11       2017-11-21T19:39:43.000Z
#                                            17.29.11       2017-11-21T19:39:43.000Z
# 😱 $1,145 iPhone Case!!                     18.04.02       2018-02-02T23:33:00.000Z
#                                            18.05.02       2018-02-02T23:33:00.000Z
#                                            18.06.02       2018-02-02T23:33:00.000Z
#
#                                                                                                     tags_US  \
# title                                      trending_date
# #184 Making a PCB using EasyEDA. // Review 17.07.12       MickMake|"electronics"|"embedded"|"maker"|"diy...
# #23 Feed The Homeless | One List, One Life 17.01.12       homeless|"experiment"|"people"|"man"|"singing"...
#                                            17.02.12       homeless|"experiment"|"people"|"man"|"singing"...
#                                            17.03.12       homeless|"experiment"|"people"|"man"|"singing"...
#                                            17.04.12       homeless|"experiment"|"people"|"man"|"singing"...
# ...                                                                                                     ...
# 🎃 How to make Pumpkin Pie Mistakes         17.28.11       ijustine|"how to make pumpkin pie"|"pumpkin pi...
#                                            17.29.11       ijustine|"how to make pumpkin pie"|"pumpkin pi...
# 😱 $1,145 iPhone Case!!                     18.04.02       ijustine|"gray international"|"most expensive ...
#                                            18.05.02       ijustine|"gray international"|"most expensive ...
#                                            18.06.02       ijustine|"gray international"|"most expensive ...
#
#                                                           views_US  likes_US  \
# title                                      trending_date
# #184 Making a PCB using EasyEDA. // Review 17.07.12           3237       161
# #23 Feed The Homeless | One List, One Life 17.01.12          32385       568
#                                            17.02.12          40644       667
#                                            17.03.12          41274       683
#                                            17.04.12          41742       707
# ...                                                            ...       ...
# 🎃 How to make Pumpkin Pie Mistakes         17.28.11         186407      8034
#                                            17.29.11         193223      8141
# 😱 $1,145 iPhone Case!!                     18.04.02         408713     15040
#                                            18.05.02         673040     18904
#                                            18.06.02         734863     19965
#
#                                                           dislikes_US  \
# title                                      trending_date
# #184 Making a PCB using EasyEDA. // Review 17.07.12                 2
# #23 Feed The Homeless | One List, One Life 17.01.12                77
#                                            17.02.12                85
#                                            17.03.12                85
#                                            17.04.12                86
# ...                                                               ...
# 🎃 How to make Pumpkin Pie Mistakes         17.28.11               301
#                                            17.29.11               302
# 😱 $1,145 iPhone Case!!                     18.04.02              2038
#                                            18.05.02              3852
#                                            18.06.02              4110
#
#                                                           comment_count_US  \
# title                                      trending_date
# #184 Making a PCB using EasyEDA. // Review 17.07.12                     35
# #23 Feed The Homeless | One List, One Life 17.01.12                     97
#                                            17.02.12                    106
#                                            17.03.12                    110
#                                            17.04.12                    112
# ...                                                                    ...
# 🎃 How to make Pumpkin Pie Mistakes         17.28.11                   1211
#                                            17.29.11                   1226
# 😱 $1,145 iPhone Case!!                     18.04.02                   2617
#                                            18.05.02                   3639
#                                            18.06.02                   3553
#
#                                                                                        thumbnail_link_US  \
# title                                      trending_date
# #184 Making a PCB using EasyEDA. // Review 17.07.12       https://i.ytimg.com/vi/BPmgDhwbd1w/default.jpg
# #23 Feed The Homeless | One List, One Life 17.01.12       https://i.ytimg.com/vi/4qakFfGRV4E/default.jpg
#                                            17.02.12       https://i.ytimg.com/vi/4qakFfGRV4E/default.jpg
#                                            17.03.12       https://i.ytimg.com/vi/4qakFfGRV4E/default.jpg
#                                            17.04.12       https://i.ytimg.com/vi/4qakFfGRV4E/default.jpg
# ...                                                                                                  ...
# 🎃 How to make Pumpkin Pie Mistakes         17.28.11       https://i.ytimg.com/vi/bAfn2duIlN8/default.jpg
#                                            17.29.11       https://i.ytimg.com/vi/bAfn2duIlN8/default.jpg
# 😱 $1,145 iPhone Case!!                     18.04.02       https://i.ytimg.com/vi/r3J784MSRyQ/default.jpg
#                                            18.05.02       https://i.ytimg.com/vi/r3J784MSRyQ/default.jpg
#                                            18.06.02       https://i.ytimg.com/vi/r3J784MSRyQ/default.jpg
#
#                                                           ...  tags_IN  \
# title                                      trending_date  ...
# #184 Making a PCB using EasyEDA. // Review 17.07.12       ...      NaN
# #23 Feed The Homeless | One List, One Life 17.01.12       ...      NaN
#                                            17.02.12       ...      NaN
#                                            17.03.12       ...      NaN
#                                            17.04.12       ...      NaN
# ...                                                       ...      ...
# 🎃 How to make Pumpkin Pie Mistakes         17.28.11       ...      NaN
#                                            17.29.11       ...      NaN
# 😱 $1,145 iPhone Case!!                     18.04.02       ...      NaN
#                                            18.05.02       ...      NaN
#                                            18.06.02       ...      NaN
#
#                                                           views_IN  likes_IN  \
# title                                      trending_date
# #184 Making a PCB using EasyEDA. // Review 17.07.12            NaN       NaN
# #23 Feed The Homeless | One List, One Life 17.01.12            NaN       NaN
#                                            17.02.12            NaN       NaN
#                                            17.03.12            NaN       NaN
#                                            17.04.12            NaN       NaN
# ...                                                            ...       ...
# 🎃 How to make Pumpkin Pie Mistakes         17.28.11            NaN       NaN
#                                            17.29.11            NaN       NaN
# 😱 $1,145 iPhone Case!!                     18.04.02            NaN       NaN
#                                            18.05.02            NaN       NaN
#                                            18.06.02            NaN       NaN
#
#                                                          dislikes_IN  \
# title                                      trending_date
# #184 Making a PCB using EasyEDA. // Review 17.07.12              NaN
# #23 Feed The Homeless | One List, One Life 17.01.12              NaN
#                                            17.02.12              NaN
#                                            17.03.12              NaN
#                                            17.04.12              NaN
# ...                                                              ...
# 🎃 How to make Pumpkin Pie Mistakes         17.28.11              NaN
#                                            17.29.11              NaN
# 😱 $1,145 iPhone Case!!                     18.04.02              NaN
#                                            18.05.02              NaN
#                                            18.06.02              NaN
#
#                                                          comment_count_IN  \
# title                                      trending_date
# #184 Making a PCB using EasyEDA. // Review 17.07.12                   NaN
# #23 Feed The Homeless | One List, One Life 17.01.12                   NaN
#                                            17.02.12                   NaN
#                                            17.03.12                   NaN
#                                            17.04.12                   NaN
# ...                                                                   ...
# 🎃 How to make Pumpkin Pie Mistakes         17.28.11                   NaN
#                                            17.29.11                   NaN
# 😱 $1,145 iPhone Case!!                     18.04.02                   NaN
#                                            18.05.02                   NaN
#                                            18.06.02                   NaN
#
#                                                          thumbnail_link_IN  \
# title                                      trending_date
# #184 Making a PCB using EasyEDA. // Review 17.07.12                    NaN
# #23 Feed The Homeless | One List, One Life 17.01.12                    NaN
#                                            17.02.12                    NaN
#                                            17.03.12                    NaN
#                                            17.04.12                    NaN
# ...                                                                    ...
# 🎃 How to make Pumpkin Pie Mistakes         17.28.11                    NaN
#                                            17.29.11                    NaN
# 😱 $1,145 iPhone Case!!                     18.04.02                    NaN
#                                            18.05.02                    NaN
#                                            18.06.02                    NaN
#
#                                                           comments_disabled_IN  \
# title                                      trending_date
# #184 Making a PCB using EasyEDA. // Review 17.07.12                        NaN
# #23 Feed The Homeless | One List, One Life 17.01.12                        NaN
#                                            17.02.12                        NaN
#                                            17.03.12                        NaN
#                                            17.04.12                        NaN
# ...                                                                        ...
# 🎃 How to make Pumpkin Pie Mistakes         17.28.11                        NaN
#                                            17.29.11                        NaN
# 😱 $1,145 iPhone Case!!                     18.04.02                        NaN
#                                            18.05.02                        NaN
#                                            18.06.02                        NaN
#
#                                                          ratings_disabled_IN  \
# title                                      trending_date
# #184 Making a PCB using EasyEDA. // Review 17.07.12                      NaN
# #23 Feed The Homeless | One List, One Life 17.01.12                      NaN
#                                            17.02.12                      NaN
#                                            17.03.12                      NaN
#                                            17.04.12                      NaN
# ...                                                                      ...
# 🎃 How to make Pumpkin Pie Mistakes         17.28.11                      NaN
#                                            17.29.11                      NaN
# 😱 $1,145 iPhone Case!!                     18.04.02                      NaN
#                                            18.05.02                      NaN
#                                            18.06.02                      NaN
#
#                                                          video_error_or_removed_IN  \
# title                                      trending_date
# #184 Making a PCB using EasyEDA. // Review 17.07.12                            NaN
# #23 Feed The Homeless | One List, One Life 17.01.12                            NaN
#                                            17.02.12                            NaN
#                                            17.03.12                            NaN
#                                            17.04.12                            NaN
# ...                                                                            ...
# 🎃 How to make Pumpkin Pie Mistakes         17.28.11                            NaN
#                                            17.29.11                            NaN
# 😱 $1,145 iPhone Case!!                     18.04.02                            NaN
#                                            18.05.02                            NaN
#                                            18.06.02                            NaN
#
#                                                           description_IN
# title                                      trending_date
# #184 Making a PCB using EasyEDA. // Review 17.07.12                  NaN
# #23 Feed The Homeless | One List, One Life 17.01.12                  NaN
#                                            17.02.12                  NaN
#                                            17.03.12                  NaN
#                                            17.04.12                  NaN
# ...                                                                  ...
# 🎃 How to make Pumpkin Pie Mistakes         17.28.11                  NaN
#                                            17.29.11                  NaN
# 😱 $1,145 iPhone Case!!                     18.04.02                  NaN
#                                            18.05.02                  NaN
#                                            18.06.02                  NaN
#
# [41103 rows x 28 columns]
